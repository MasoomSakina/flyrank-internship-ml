# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MasoomSakina/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Lane: Freestyle Direction — Growth / Recovery / Momentum Prediction (Anomaly & Volatility Detection)
#
# **Why this lane:**
# I chose this lane because tracking content performance over time allows us to systematically identify high-impact pages suffering from traffic decay. By analyzing items that exhibit both high impression volume ($\ge 1,000$ impressions) and downward trend trajectories, we can prioritize high-exposure anomalies and execute targeted content refreshes to recover lost traffic efficiently.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### 2. The Decision, Action, and Cost
#
# * **What decision does this work improve?**
#   Determining which declining content pages yield the highest risk of lost traffic and require immediate content updates or structural intervention versus pages experiencing normal variance.
#
# * **Who acts on it?**
#   Content strategists, SEO leads, and editorial teams responsible for updating decaying pages and re-optimizing target keywords.
#
# * **What does a wrong recommendation cost?**
#   * *False Positive (flagging stable content as declining):* Wastes valuable editorial resources and budget refreshing content that didn't need intervention.
#   * *False Negative (missing a high-impact declining page):* Leads to compounding organic traffic loss, diminished site authority, and missed conversion opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load dataset
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

total_pages = len(df)
declining_pages = (df['trend_direction'] == 'down').sum()
high_exposure_declining = df[(df['trend_direction'] == 'down') & (df['impressions_90d'] >= 1000)].shape[0]

print(f"Total Content Items: {total_pages:,}")
print(f"Declining Items: {declining_pages:,} ({declining_pages/total_pages:.2%})")
print(f"High-Exposure Downward Trend Items: {high_exposure_declining:,}")
# Out:
# Total Content Items: 30,000
# Declining Items: 16,262 (54.21%)
# High-Exposure Downward Trend Items: 8,031

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### 4. What I Can and Cannot Claim
#
# * **What my work CAN claim (Observed & Directional Decision-Support):**
#   * **Observed Trends:** Historical performance patterns, loss of impression share, and declining performance trajectories within the dataset.
#   * **Directional Signals:** Risk scores and anomaly indicators that flag pages showing significant negative variance relative to baseline performance.
#   * **Prioritization Framework:** Actionable, data-driven ranking to help teams allocate refresh resources to high-exposure pages efficiently.
#
# * **What my work CANNOT claim (Causal Proof & Search Engine Internal Logic):**
#   * **No Causal Proof:** The model cannot prove *why* a page is declining (e.g., algorithm updates vs. shifting user intent vs. technical site changes).
#   * **No Search Engine Guarantees:** This work does not claim to predict search engine ranking algorithms or guarantee that refreshing a flagged page will reverse traffic decay.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# * [x] Every section above is filled — markdown thinking AND the code that backs it
# * [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# * [x] No client names, URLs, or private queries anywhere
# * [x] My claims use careful words: observed, measured, directional, decision-support
# * [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
